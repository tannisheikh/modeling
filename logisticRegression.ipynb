# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/status.csv')

# %%
df.head()
# Out:
#    Age  Married_Status
# 0   36             0.0
# 1   27             1.0
# 2   24             1.0
# 3   48             1.0
# 4   48             0.0

# %%
df.isnull().sum()
# Out:
# Age               0
# Married_Status    3
# dtype: int64

# %%
handle = df['Married_Status'].median()
handle
# Out:
# 1.0

# %%
df.Married_Status = df.Married_Status.fillna(handle)

# %%
df.isnull().sum()
# Out:
# Age               0
# Married_Status    0
# dtype: int64

# %%
x = df[['Age']]
x.head()
# Out:
#    Age
# 0   36
# 1   27
# 2   24
# 3   48
# 4   48

# %%
y = df['Married_Status']
y.head()
# Out:
# 0    0.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0
# Name: Married_Status, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3 , random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1., 1., 0., 1., 1., 1., 1., 1., 1., 0., 1., 1., 1., 1., 1., 1.])

# %%
model.score(x_test,y_test)
# Out:
# 0.6875
