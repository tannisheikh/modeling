# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Salary Data.csv')

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
x = df[['Experience Years']]
x.head()
# Out:
#    Experience Years
# 0               1.1
# 1               1.2
# 2               1.3
# 3               1.5
# 4               2.0

# %%
y = df['Salary']
y.head()
# Out:
# 0    39343
# 1    42774
# 2    46205
# 3    37731
# 4    43525
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 1)

# %%
plt.scatter(x , y)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
x.mean()
# Out:
# Experience Years    5.1525
# dtype: float64

# %%
y.mean()
# Out:
# 74743.625

# %%
plt.scatter(x , y)
plt.scatter(x.mean() , y.mean())

# %%
reg.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([ 37546.13438102, 101431.37476946,  39482.05075642,  72392.62913835,
#         84976.08557849,  90783.83470472,  74328.54551375, 126598.28764975])

# %%
reg.score(x_test,y_test)
# Out:
# 0.9603121884009412
